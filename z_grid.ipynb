# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dz0 = 3.2e-4

N_pix = 500

idx_z = np.arange(N_pix)

dz = dz0 * (1 + (5*idx_z/N_pix)**2.5)

z_grid = np.cumsum(dz)

plt.plot(z_grid)

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
import astropy.units as u  # Only needed for psipy interface
from psipy.model import MASOutput

mas_folder = "./corona"

model = MASOutput(mas_folder)

# %%
rho = model["rho"]

# %%
plt.plot(np.diff(rho.r_coords))   
plt.yscale("log")
plt.show()

# %%
plt.plot((rho.r_coords.value))   
plt.show()
# Out:
# /tmp/ipykernel_3360848/4220216833.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
